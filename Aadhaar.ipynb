# %% [markdown]
# <a href="https://colab.research.google.com/github/CathyShalu/Assignment1/blob/main/Aadhaar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pymongo
client = pymongo.MongoClient("mongodb+srv://catyshalu:DX3bjbuvZRPtcexY@cluster0.qnflhwm.mongodb.net/?retryWrites=true&w=majority")

# %%
#creating database
db = client.Aadhar
records=db.New

# %%
data1={
    "name" : "catherine",
    "DOB" : 7/1/1993,
    "Address" : ["74/c Havelock Road, udhagai"],
    "Pincode" :643001,
    "Gender" : "Female",   
    "Educational Qualification" : "BE",
    "Stream" : "EEE",
    "Email id" : "catyshalu46@gmail.com"
}
records.insert_one(data1)

# %%
from PIL import Image
import io
 
im = Image.open("/content/download.png")
 
image_bytes = io.BytesIO()
im.save(image_bytes, format='PNG')
 
dict1 = {
   "name":"catherine",
   'image': image_bytes.getvalue()
}
 
records.insert_one(dict1)

# %%
#Reading image from Mongo for profile photo
#from pymongo import MongoClient
from PIL import Image
import io
#import matplotlib.pyplot as plt
 
 
 
retrival = records.find_one({"name":"aadhar"})
#print(retrival["_id"])
 
pil_img = Image.open(io.BytesIO(retrival['image']))
#plt.imshow(pil_img)
#plt.show()
pil_img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=343x147 at 0x7FE52F1F1850>

# %%
d1={"aadhar no":279522392044,"name":"cathy"}
records.insert_one(d1)

# %%
# !pip install qrcode
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import qrcode
a="my aadhar"
img = qrcode.make(a)
type(img)  # qrcode.image.pil.PilImage
img.save("1.jpg")
img

# %%
myquery = {"name" : "catherine"}
newvalues = {"$set" : {"address" : "ooty","age":30}}

records.update_one(myquery,newvalues)
for x in records.find().limit(15):
  print(x)
# Out:
# {'_id': ObjectId('63a41051e8d2b72dc44b25a5'), 'name': 'catherine', 'DOB': 0.0035122930255895636, 'Address': ['74/c Havelock Road, udhagai'], 'Pincode': 643001, 'Gender': 'Female', 'Educational Qualification': 'BE', 'Stream': 'EEE', 'Email id': 'catyshalu46@gmail.com', 'address': 'ooty', 'age': 30}
# ...
